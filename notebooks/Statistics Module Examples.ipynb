# %% [markdown]
# # Statistics Module Examples
# ---
# Timothy Helton

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd

from k2datascience import stats as k2stats

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

# %%
transaction_data = pd.Series(np.random.beta(100, 20, 10000) * 100)
k2stats.distribution_plot(data=transaction_data,
                          title='E-Commerce Transaction Data',
                          x_label='US Dollars')
